# %% [markdown]
# <h2 style="background-color:white; color:black; text-align:center;
#     font-size:30px; font-weight:bold;padding:10px;">AI Tutor</h1>

# %%
from openai import OpenAI

# %%
client = OpenAI(base_url="http://localhost:11434/v1",api_key="ollama")

# %%
while True:
    user=input("Ask your question: ")
    if user.lower()=="exit":
        break
    response = client.chat.completions.create(model="llama3:8b",messages=[{"role":"system","content":"You are an AI tutor. Answer the student's question clearly."},{"role": "user", "content": user}])
    print(response.choices[0].message.content)
# Out:
# Ask your question:  which is the national bird of india?
# That's an easy one!
#
# The national bird of India is the Indian Peafowl, also known as the Peacock (Pavo cristatus).
# Ask your question:  exit
